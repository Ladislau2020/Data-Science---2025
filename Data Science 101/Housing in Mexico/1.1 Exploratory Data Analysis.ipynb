# %% [markdown]
# # 1.1. Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %% [markdown]
# Exploratory data analysis (EDA), is where you get a feel for your data by summarizing its main characteristics using descriptive statistics and data visualization. A good way to plan your EDA is by looking each column and asking yourself questions what it says about your dataset.

# %% [markdown]
# ## Import Data

# %% [markdown]
# **Task 1.3.1:** Read the CSV file. Be sure to check that all your columns are the correct data type before you go to the next task.

# %%
pip install openpyxl

# %%
df1 = pd.read_excel('/Workspace/Data-Science---2025/Data Science 101/Housing in Mexico/real-estate.xlsx', sheet_name='mexico-real-estate-1')
df2 = pd.read_excel('/Workspace/Data-Science---2025/Data Science 101/Housing in Mexico/real-estate.xlsx', sheet_name='mexico-real-estate-2')
df3 = pd.read_excel('/Workspace/Data-Science---2025/Data Science 101/Housing in Mexico/real-estate.xlsx', sheet_name='mexico-real-estate-3')

# %% [markdown]
# **Task 1.3.2:** Check for data quality.

# %%
for df in [df1, df2, df3]:
    df.info()

# %% [markdown]
# - The code above shoows us that **one of the tables has 1 column less** than the others and **the three tables have missing values in lat and lon columns**.
# - There are many NaN in lat and lon columns
# - Price_usd in the first table (df1) is `object` when it should be `float`.

# %% [markdown]
# ### Clean df1

# %% [markdown]
# **Task 1.3.3:** Inspect df1 by taking a closer look and cleaning on df1.

# %%
df1.head()

# %% [markdown]
# **Task 1.3.4:** Clean df1 by dropping rows with NaN values. Then remove the "$" and "," characters from "price_usd" and recast the values in the column as floats.

# %%
# Drop null values from df1
df1 = df1.dropna()
df1.info()

# %%
# Clean "price_usd" column in df1
df1['price_usd'] = (
    df1['price_usd']
    .str.replace('$', '', regex=False)
    .str.replace(',', '')
    .astype(float))
df1.info()

# %% [markdown]
# ### Clean df2

# %% [markdown]
# Now it's time to tackle df2. Take a moment to inspect it using the same commands you used before. You'll notice that it has the same issue of NaN values, but there's a new problem, too: The home prices are in Mexican pesos ("price_mxn"), not US dollars ("price_usd"). If we want to compare all the home prices in this dataset, they all need to be in the same currency.

# %% [markdown]
# **Task 1.3.5:** First, drop rows with NaN values in df2. Next, use the "price_mxn" column to create a new column named "price_usd". (Keep in mind that, when this data was collected in 2014, a dollar cost 19 pesos.) Finally, drop the "price_mxn" from the DataFrame.

# %%
# Drop null values from df2
df1.dropna(inplace=True)
df1.info()

# %%
# Create "price_usd" column for df2 (19 pesos to the dollar in 2014)
df2["price_usd"] = df2["price_mxn"] / 19
df2.head()

# %%
# Drop "price_mxn" column from df2
df2 = df2.drop(columns=["price_mxn"])
df2.head()

# %% [markdown]
# ### Clean df3

# %%
df3.head()

# %% [markdown]
# We notice that we still have NaN values, but there are two new problems:
#
# - Instead of separate "lat" and "lon" columns, there's a single "lat-lon" column.
# - Instead of a "state" column, there's a "place_with_parent_names" column.

# %% [markdown]
# **Task 1.3.6:** Drop rows with NaN values in df3. Then use the split method to create two new columns from "lat-lon" named "lat" and "lon", respectively.

# %%
# Drop null values from df3
df3.dropna(inplace=True)


# Create "lat" and "lon" columns for df3
df3[["lat", "lon"]] = df3["lat-lon"].str.split(",", expand=True)
df3 = df3.drop(columns=["lat-lon"])
df3.head()

# %% [markdown]
# **Task 1.3.6:** Use the split method again, this time to extract the state for every house. (Note that the state name always appears after "México|" in each string.) Use this information to create a "state" column. Finally, drop the "place_with_parent_names" and "lat-lon" columns from the DataFrame.

# %%
# Create "state" column for df3
df3["state"] = df3["place_with_parent_names"].str.split("|", expand=True)[2]

# Drop "place_with_parent_names" and "lat-lon" from df3
df3 = df3.drop(columns=["place_with_parent_names"])
df3.head()

# %% [markdown]
# ### Concatenate DataFrames

# %%
# Concatenate df1, df2, and df3
df = pd.concat([df1, df2, df3])
df.head()
